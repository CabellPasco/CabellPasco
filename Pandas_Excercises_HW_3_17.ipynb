# %% [markdown]
# <a href="https://colab.research.google.com/github/CabellPasco/CabellPasco/blob/main/Pandas_Excercises_HW_3_17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pandas exercises 1
#
# 1. Import dependencies

# %%
import pandas as pd

# %% [markdown]
# ---

# %%
list = [98, 24, 46, 87, 33]

# %% [markdown]
# 2. Convert `list` to a pandas series using `pd.Series`

# %%
mypnd = pd.Series(list)

# %% [markdown]
# 3. Take the above series and add an index that starts at 2 and steps by 3

# %%
mypnd = pd.DataFrame(index = [2,5,8,11,14])

# %% [markdown]
# 4. Create a dictionary of 4 names, ages, and careers
# Convert this dictionary to a pandas dataframe: `df`.
# Print the dataframe.

# %%
directory = {
    "name" : ["Tom", "Jerry","Ron", "Swanson"],
    "age" : [22, 20, 43, 44],
    "career" : ["exterminator", "taster", "woodworker", "park guide"]
}

df = pd.DataFrame(directory)
df
# Out:
#       name  age        career
# 0      Tom   22  exterminator
# 1    Jerry   20        taster
# 2      Ron   43    woodworker
# 3  Swanson   44    park guide

# %% [markdown]
# 5. Name the index of `df` 'participant_id'.
# Print `df`.

# %%
df.index.name = "participant_id"
df
# Out:
#                    name  age        career
# participant_id
# 0                   Tom   22  exterminator
# 1                 Jerry   20        taster
# 2                   Ron   43    woodworker
# 3               Swanson   44    park guide

# %% [markdown]
# 6. Use a pandas function to determine the data types of the columns of `df`.

# %%
df.dtypes
# Out:
# name      object
# age        int64
# career    object
# dtype: object

# %% [markdown]
# 7. Using bracket notation, reference column `name`

# %%
df["name"]
# Out:
# participant_id
# 0        Tom
# 1      Jerry
# 2        Ron
# 3    Swanson
# Name: name, dtype: object

# %% [markdown]
# 8. Using dot notation, reference column `name`

# %%
df.name
# Out:
# participant_id
# 0        Tom
# 1      Jerry
# 2        Ron
# 3    Swanson
# Name: name, dtype: object

# %% [markdown]
# 8. Reference column `name` and have it returned in a dataframe.

# %%
newdf = pd.DataFrame(df.name)
newdf
# Out:
#                    name
# participant_id
# 0                   Tom
# 1                 Jerry
# 2                   Ron
# 3               Swanson

# %% [markdown]
# 9. Show the 3rd element in column `career`.

# %%
df.career[2]
# Out:
# 'woodworker'

# %% [markdown]
# 10.  Load the `iris` dataset that we used in class.  Use `iris` as the name of your data frame.

# %%
import seaborn as sns
iris = sns.load_dataset('iris')

display(iris.to_string()) #displays the whole data frame so the start/end of each species is visible
# Out:
# '     sepal_length  sepal_width  petal_length  petal_width     species\n0             5.1          3.5           1.4          0.2      setosa\n1             4.9          3.0           1.4          0.2      setosa\n2             4.7          3.2           1.3          0.2      setosa\n3             4.6          3.1           1.5          0.2      setosa\n4             5.0          3.6           1.4          0.2      setosa\n5             5.4          3.9           1.7          0.4      setosa\n6             4.6          3.4           1.4          0.3      setosa\n7             5.0          3.4           1.5          0.2      setosa\n8             4.4          2.9           1.4          0.2      setosa\n9             4.9          3.1           1.5          0.1      setosa\n10            5.4          3.7           1.5          0.2      setosa\n11            4.8          3.4           1.6          0.2      setosa\n12            4.8          3.0           1.4          0.1      setosa\n13 
# ...

# %% [markdown]
# 11.  What is the correlation between the variables `sepal_length` and `sepal_width` for all the irises?

# %%
iris[['sepal_length','sepal_width']].corr()
# Out:
#               sepal_length  sepal_width
# sepal_length       1.00000     -0.11757
# sepal_width       -0.11757      1.00000

# %% [markdown]
# 12.  Which of the three species has the highest correlation between `sepal_length` and `sepal_width`?  Show any calculations you use to support your answer.

# %%
#create seperate groups for each species to compare sepal length/width
setosa = iris.iloc[:50]
versicolor = iris.iloc[50:100]
virginica = iris.iloc[100:]

#run corr for each species
print("setosa correlation:")
print(setosa[['sepal_length','sepal_width']].corr())

print("versicolor correlation:")
print(versicolor[['sepal_length','sepal_width']].corr())

print("virginica correlation:")
print(virginica[['sepal_length','sepal_width']].corr())

print("these calculations show that setosa has the highest correlation between sepal legnth and sepal width")
# Out:
# setosa correlation:
#               sepal_length  sepal_width
# sepal_length      1.000000     0.742547
# sepal_width       0.742547     1.000000
# versicolor correlation:
#               sepal_length  sepal_width
# sepal_length      1.000000     0.525911
# sepal_width       0.525911     1.000000
# virginica correlation:
#               sepal_length  sepal_width
# sepal_length      1.000000     0.457228
# sepal_width       0.457228     1.000000
# these calculations show that setosa has the highest correlation between sepal legnth and sepal width

# %% [markdown]
# 13.  Among the four variables, the two that are most negatively correlated (overall) are `sepal_width` and `petal_length`.  (How do we know this?)  Determine the same thing but for each species separately:  for each species, which two variables have the most negative (or the least positive) correlation?  Again, include calculations to support your answer.

# %%
print("This dataframe shows us that sepal width and petal legnth are overall most negatively correlated")
iris.corr()
# Out:
# This dataframe shows us that sepal width and petal legnth are overall most negatively correlated
# <ipython-input-27-c141827224f1>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   iris.corr()
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
#SETOSA
print("Setosa correlations between data sets:")
print(setosa[['sepal_length','sepal_width']].corr())
print(setosa[['sepal_length','petal_length']].corr())
print(setosa[['sepal_length','petal_width']].corr())
print(setosa[['sepal_width','petal_length']].corr())
print(setosa[['sepal_width','petal_width']].corr())
print(setosa[['petal_length','petal_width']].corr())
# Out:
# Setosa correlations between data sets:
#               sepal_length  sepal_width
# sepal_length      1.000000     0.742547
# sepal_width       0.742547     1.000000
#               sepal_length  petal_length
# sepal_length      1.000000      0.267176
# petal_length      0.267176      1.000000
#               sepal_length  petal_width
# sepal_length      1.000000     0.278098
# petal_width       0.278098     1.000000
#               sepal_width  petal_length
# sepal_width        1.0000        0.1777
# petal_length       0.1777        1.0000
#              sepal_width  petal_width
# sepal_width     1.000000     0.232752
# petal_width     0.232752     1.000000
#               petal_length  petal_width
# petal_length       1.00000      0.33163
# petal_width        0.33163      1.00000

# %%
#VERSICOLOR
print("Versicolor correlations between data sets:")
print(versicolor[['sepal_length','sepal_width']].corr())
print(versicolor[['sepal_length','petal_length']].corr())
print(versicolor[['sepal_length','petal_width']].corr())
print(versicolor[['sepal_width','petal_length']].corr())
print(versicolor[['sepal_width','petal_width']].corr())
print(versicolor[['petal_length','petal_width']].corr())
# Out:
# Versicolor correlations between data sets:
#               sepal_length  sepal_width
# sepal_length      1.000000     0.525911
# sepal_width       0.525911     1.000000
#               sepal_length  petal_length
# sepal_length      1.000000      0.754049
# petal_length      0.754049      1.000000
#               sepal_length  petal_width
# sepal_length      1.000000     0.546461
# petal_width       0.546461     1.000000
#               sepal_width  petal_length
# sepal_width      1.000000      0.560522
# petal_length     0.560522      1.000000
#              sepal_width  petal_width
# sepal_width     1.000000     0.663999
# petal_width     0.663999     1.000000
#               petal_length  petal_width
# petal_length      1.000000     0.786668
# petal_width       0.786668     1.000000

# %%
#VIRGINICA
print("Virginica correlations between data sets:")
print(virginica[['sepal_length','sepal_width']].corr())
print(virginica[['sepal_length','petal_length']].corr())
print(virginica[['sepal_length','petal_width']].corr())
print(virginica[['sepal_width','petal_length']].corr())
print(virginica[['sepal_width','petal_width']].corr())
print(virginica[['petal_length','petal_width']].corr())
# Out:
# Virginica correlations between data sets:
#               sepal_length  sepal_width
# sepal_length      1.000000     0.457228
# sepal_width       0.457228     1.000000
#               sepal_length  petal_length
# sepal_length      1.000000      0.864225
# petal_length      0.864225      1.000000
#               sepal_length  petal_width
# sepal_length      1.000000     0.281108
# petal_width       0.281108     1.000000
#               sepal_width  petal_length
# sepal_width      1.000000      0.401045
# petal_length     0.401045      1.000000
#              sepal_width  petal_width
# sepal_width     1.000000     0.537728
# petal_width     0.537728     1.000000
#               petal_length  petal_width
# petal_length      1.000000     0.322108
# petal_width       0.322108     1.000000

# %% [markdown]
# 14.  Once again, the variables `sepal_width` and `petal_length` are negatively correlated.  But for each individual species, these two variables are positively correlated.  How is this possible?  Explain this phenomenon.  Use a data visualization if it helps.

# %%
import matplotlib.pyplot as plt
plt.scatter(iris["sepal_width"], iris["petal_length"])
print("While each individual species has a low, positive correlation between sepal width and petal length, the trend dissappears when the groups are merged (Simpson's Paradox)")
# Out:
# While each individual species has a low, positive correlation between sepal width and petal length, the trend dissappears when the groups are merged (Simpson's Paradox)
